# %% [markdown]
# <figure>
# <img src='https://upload.wikimedia.org/wikipedia/commons/thumb/d/d3/MercadoLibre_Logotipo.svg/1920px-MercadoLibre_Logotipo.svg.png' width="350" height="100" />
# <figcaption></figcaption>
# </figure>
#
# # **AB Testing en MercadoLibre**
# ## **Challenge Experimentos Melidata**
# ### **Autor:** Julian David Rueda Sosa

# %% [markdown]
# ## **Preparación del entorno**

# %% [markdown]
# Definimos los paquetes que vamos a utilizar

# %%
# Preparamos el entorno

import pandas as pd
import numpy as np
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

# %% [markdown]
# Previamente hemos descargado los datos compartidos de [google drive](https://drive.google.com/file/d/1q-kVDe62HY-6SbLsetsi1s1vvYgzPUOi/view?usp=sharing) y los hemos cargado en nuestro [Github](https://github.com/JdrSosa/MELI), de tal modo que ahora importamos el dataset directamente desde nuestro repositorio:

# %%
# Cargamos los datos y creamos el dataframe a utilizar

df_0 = pd.read_csv('https://raw.githubusercontent.com/JdrSosa/MELI/main/Experiments.csv',sep=",")
df_0.head()
# Out:
#   event_name      item_id                     timestamp site  \
# 0     SEARCH          NaN  2021-08-02T23:55:38.966-0400  MLA
# 1    PRODUCT  882352139.0  2021-08-02T23:55:51.673-0400  MLA
# 2    PRODUCT  655266729.0  2021-08-02T23:56:16.083-0400  MLA
# 3    PRODUCT  761520929.0  2021-08-02T23:56:29.989-0400  MLA
# 4    PRODUCT  757586409.0  2021-08-02T23:56:47.887-0400  MLA
#
#                                          experiments  user_id
# 0  {searchbackend/recommended-products=6157, mcli...  3204901
# 1  {qadb/sa-on-vip=6695, vip/showV2V3BoxMessages=...  3204901
# 2  {qadb/sa-on-vip=6695, vip/showV2V3BoxMessages=...  3204901
# 3  {search/remove-ecn-tag=4954, qadb/sa-on-vip=66...  3204901
# 4  {search/remove-ecn-tag=4954, qadb/sa-on-vip=66...  3204901

# %%
# Dimensiones del Dataframe
df_0.shape
# Out:
# (141553, 6)

# %%
# Cantidad de valores únicos por vaeriable
df_0.nunique()
# Out:
# event_name          6
# item_id         45273
# timestamp      140582
# site                1
# experiments      1551
# user_id          7817
# dtype: int64

# %%
# Tipos de variables
df_0.dtypes
# Out:
# event_name      object
# item_id        float64
# timestamp       object
# site            object
# experiments     object
# user_id          int64
# dtype: object

# %% [markdown]
# ## **Preprocesado de los datos**

# %% [markdown]
# Luego de observar los datos, vemos que podemos realizar algunos ajustes para trabajarlos de una forma más amigable. Inicialmente, vamos a agregar dos variables complementarias a la marca de tiempo que es de tipo "object", primero "datetime" que nos puede ayudar más adelante para ordenar la información y segundo, la variable "date" que nos puede permitir realizar agrupaciones por día.

# %%
# Agregamos una variable llamada "date" que es una tranformación de la variable "timestamp" a formato fecha

df_0["datetime"] = pd.to_datetime(df_0["timestamp"], format="%Y-%m-%dT%H:%M:%S.%f%z")
df_0["date"] = pd.to_datetime(df_0["datetime"]).dt.date
df_0.head()
# Out:
#   event_name      item_id                     timestamp site  \
# 0     SEARCH          NaN  2021-08-02T23:55:38.966-0400  MLA
# 1    PRODUCT  882352139.0  2021-08-02T23:55:51.673-0400  MLA
# 2    PRODUCT  655266729.0  2021-08-02T23:56:16.083-0400  MLA
# 3    PRODUCT  761520929.0  2021-08-02T23:56:29.989-0400  MLA
# 4    PRODUCT  757586409.0  2021-08-02T23:56:47.887-0400  MLA
#
#                                          experiments  user_id  \
# 0  {searchbackend/recommended-products=6157, mcli...  3204901
# 1  {qadb/sa-on-vip=6695, vip/showV2V3BoxMessages=...  3204901
# 2  {qadb/sa-on-vip=6695, vip/showV2V3BoxMessages=...  3204901
# 3  {search/remove-ecn-tag=4954, qadb/sa-on-vip=66...  3204901
# 4  {search/remove-ecn-tag=4954, qadb/sa-on-vip=66...  3204901
#
#                           datetime        date
# 0 2021-08-02 23:55:38.966000-04:00  2021-08-02
# 1 2021-08-02 23:55:51.673000-04:00  2021-08-02
# 2 2021-08-02 23:56:16.083000-04:00  2021-08-02
# 3 2021-08-02 23:56:29.989000-04:00  2021-08-02
# 4 2021-08-02 23:56:47.887000-04:00  2021-08-02

# %%
# Presentamos el primer registro de la variable "experiments" para ver como esta compuesta
df_0.experiments[0]
# Out:
# '{searchbackend/recommended-products=6157, mclics/ads-adsearch-boost-incremental-desktop-mla=3809, searchbackend/cbt-antiboost=6333, search/back-filters=5059, filters/sort-by-ranking=7057, search/best-seller-aa-testing-fail-fast-edition=4514, mclics/search-list-algorithms=5528, frontend/assetsCdnDomainMLU=DEFAULT, searchbackend/item-reputation=3824, search/remove-ecn-tag=4954, mclics/search-pads-none-desktop-mla=3478, mclics/show-pads-search-list=5146, searchbackend/seller-reputation-change=4553, cookiesConsentBanner=DEFAULT, frontend/assetsCdnDomainMLA=DEFAULT, search/best-seller-fail-fast-edition-MLA=4916, mclics/show-pads-global=5176}'

# %% [markdown]
# Ahora vamos a trabajar sobre la variable "experiments" donde vemos que tiene forma de tupla compuesta por experimento=variante y los diferentes experimentos a los que se sometió el usuario en ese momento estan separados por comas.
#
# Una vez, revisado el primer registro, vamos a construir un bucle que nos permita iterar sobre cada par de elementos y construir un diccionario con los elementos de esta variable.

# %%
# Vamos a crear un diccionario a partir de la variable "experiments" donde cada $experimento=$variant_id esta separado por una coma
# Lo probamos sobre el primer registro de la variable "experiments"

cadena = df_0.experiments[0]
diccionario = {}
pares = cadena.strip("{}").split(", ")

for par in pares:
    clave, valor = par.split("=")
    diccionario[clave] = valor
    
diccionario
# Out:
# {'searchbackend/recommended-products': '6157',
#  'mclics/ads-adsearch-boost-incremental-desktop-mla': '3809',
#  'searchbackend/cbt-antiboost': '6333',
#  'search/back-filters': '5059',
#  'filters/sort-by-ranking': '7057',
#  'search/best-seller-aa-testing-fail-fast-edition': '4514',
#  'mclics/search-list-algorithms': '5528',
#  'frontend/assetsCdnDomainMLU': 'DEFAULT',
#  'searchbackend/item-reputation': '3824',
#  'search/remove-ecn-tag': '4954',
#  'mclics/search-pads-none-desktop-mla': '3478',
#  'mclics/show-pads-search-list': '5146',
#  'searchbackend/seller-reputation-change': '4553',
#  'cookiesConsentBanner': 'DEFAULT',
#  'frontend/assetsCdnDomainMLA': 'DEFAULT',
#  'search/best-seller-fail-fast-edition-MLA': '4916',
#  'mclics/show-pads-global': '5176'}

# %% [markdown]
# Observamos la información del diccionario para el primer registro en forma de dataframe y vemos que este usuario en ese momento se sometió a 16 diferentes experimentos con sus correspondientes variantes:

# %%
# Presentamos en forma de dataframe lo correspondiente al primer registro de la variable "experiments"

pd.DataFrame(diccionario.items(), columns=['experiment_name', 'variant_id'])
# Out:
#                                       experiment_name variant_id
# 0                  searchbackend/recommended-products       6157
# 1   mclics/ads-adsearch-boost-incremental-desktop-mla       3809
# 2                         searchbackend/cbt-antiboost       6333
# 3                                 search/back-filters       5059
# 4                             filters/sort-by-ranking       7057
# 5     search/best-seller-aa-testing-fail-fast-edition       4514
# 6                       mclics/search-list-algorithms       5528
# 7                         frontend/assetsCdnDomainMLU    DEFAULT
# 8                       searchbackend/item-reputation       3824
# 9                               search/remove-ecn-tag       4954
# 10                mclics/search-pads-none-desktop-mla       3478
# 11                       mclics/show-pads-search-list       5146
# 12             searchbackend/seller-reputation-change       4553
# 13                               cookiesConsentBanner    DEFAULT
# 14                        frontend/assetsCdnDomainMLA    DEFAULT
# 15           search/best-seller-fail-fast-edition-MLA       4916
# 16                            mclics/show-pads-global       5176

# %% [markdown]
# Una vez validado lo anterior, debemos aplicarlo a todo el dataframe, para ello, vamos a construir la función "convertir_a_diccionario", con la lógica probada previamente y luego de aplica a toda la variable "experiments":

# %%
# Construimos la función "convertir_a_diccionario" a partir de lo revisado anteriormente para aplicarlo a toda la columna "experiments" del dataframe y creamos una nueva columna llamda "dict_exeriments"

def convertir_a_diccionario(cadena):
    diccionario = {}
    pares = cadena.strip("{}").split(", ")
    for par in pares:
        clave, valor = par.split("=")
        diccionario[clave] = valor
    return diccionario

df_0["dict_experiments"] = df_0["experiments"].apply(convertir_a_diccionario)
df_0.head()
# Out:
#   event_name      item_id                     timestamp site  \
# 0     SEARCH          NaN  2021-08-02T23:55:38.966-0400  MLA
# 1    PRODUCT  882352139.0  2021-08-02T23:55:51.673-0400  MLA
# 2    PRODUCT  655266729.0  2021-08-02T23:56:16.083-0400  MLA
# 3    PRODUCT  761520929.0  2021-08-02T23:56:29.989-0400  MLA
# 4    PRODUCT  757586409.0  2021-08-02T23:56:47.887-0400  MLA
#
#                                          experiments  user_id  \
# 0  {searchbackend/recommended-products=6157, mcli...  3204901
# 1  {qadb/sa-on-vip=6695, vip/showV2V3BoxMessages=...  3204901
# 2  {qadb/sa-on-vip=6695, vip/showV2V3BoxMessages=...  3204901
# 3  {search/remove-ecn-tag=4954, qadb/sa-on-vip=66...  3204901
# 4  {search/remove-ecn-tag=4954, qadb/sa-on-vip=66...  3204901
#
#                           datetime        date  \
# 0 2021-08-02 23:55:38.966000-04:00  2021-08-02
# 1 2021-08-02 23:55:51.673000-04:00  2021-08-02
# 2 2021-08-02 23:56:16.083000-04:00  2021-08-02
# 3 2021-08-02 23:56:29.989000-04:00  2021-08-02
# 4 2021-08-02 23:56:47.887000-04:00  2021-08-02
#
#                                     dict_experiments
# 0  {'searchbackend/recommended-products': '6157',...
# 1  {'qadb/sa-on-vip': '6695', 'vip/showV2V3BoxMes...
# 2  {'qadb/sa-on-vip': '6695', 'vip/showV2V3BoxMes...
# 3  {'search/remove-ecn-tag': '4954', 'qadb/sa-on-...
# 4  {'search/remove-ecn-tag': '4954', 'qadb/sa-on-...

# %% [markdown]
# Ahora, como se presenta en el [articulo de referencia ](https://medium.com/mercadolibre-tech/a-b-testing-meli-3a5ad2b4594d) vamos a ordenar los datos por ususario y datetime para visualizar toda su "cadena de navegación":

# %%
# Ordenamos el Dataframe para ver la "cadena de navegación": lista ordenada de eventos por los que ha pasado un determinado usuario

df_0 = df_0.sort_values(['user_id','datetime', 'item_id'], ascending = [True, True, True], ignore_index=True)
df_0.head()
# Out:
#    event_name      item_id                     timestamp site  \
# 0      SEARCH          NaN  2021-08-02T09:28:32.820-0400  MLA
# 1     PRODUCT  488321709.0  2021-08-02T09:29:11.073-0400  MLA
# 2      SEARCH          NaN  2021-08-02T09:29:14.581-0400  MLA
# 3     PRODUCT  993974477.0  2021-08-02T09:29:19.776-0400  MLA
# 4  CHECKOUT_1  993974477.0  2021-08-02T09:29:36.373-0400  MLA
#
#                                          experiments  user_id  \
# 0  {searchbackend/recommended-products=6158, mcli...       59
# 1  {search/remove-ecn-tag=4954, vip/showV2V3BoxMe...       59
# 2  {searchbackend/recommended-products=6158, mcli...       59
# 3  {search/remove-ecn-tag=4954, vip/showV2V3BoxMe...       59
# 4  {buyingflow/user-track=6796, buyingflow/escWeb...       59
#
#                           datetime        date  \
# 0 2021-08-02 09:28:32.820000-04:00  2021-08-02
# 1 2021-08-02 09:29:11.073000-04:00  2021-08-02
# 2 2021-08-02 09:29:14.581000-04:00  2021-08-02
# 3 2021-08-02 09:29:19.776000-04:00  2021-08-02
# 4 2021-08-02 09:29:36.373000-04:00  2021-08-02
#
#                                     dict_experiments
# 0  {'searchbackend/recommended-products': '6158',...
# 1  {'search/remove-ecn-tag': '4954', 'vip/showV2V...
# 2  {'searchbackend/recommended-products': '6158',...
# 3  {'search/remove-ecn-tag': '4954', 'vip/showV2V...
# 4  {'buyingflow/user-track': '6796', 'buyingflow/...

# %% [markdown]
# Para facilidad el tratamiento de los datos vamos a combinar lo probado anteriormente, de tal forma que convertimos "experiments" en diccionario y luego separamos dicho diccionario en dos columnas nuevas "experiment" y "variant_id" de tal modo que para cada usuario, su información se repetira tantas veces como experimentos haya tenido en cada registro:

# %%
# Construimos una función que nos permite separar en dos columnas los elementos del diccionario obteniendo $experiment_name y $variant_id 
# De tal modo que para cada usuario vamos a poder ver todos los experimentos a los que fue sometido en cada evento

def dict_to_df(row):
    dictionary = row['experiments']
    pairs = dictionary.strip("{}").split(", ")
    data = {}
    for pair in pairs:
        key, value = pair.split("=")
        data[key] = value
    df = pd.DataFrame(data.items(), columns=['experiment', 'variant_id'])
    df['user_id'] = row['user_id']
    df['event_name'] = row['event_name']
    df['item_id'] = row['item_id']
    df['timestamp'] = row['timestamp']
    df['datetime'] = row['datetime']
    df['date'] = row['date']
    df['site'] = row['site']
    return df

df_1 = df_0.apply(dict_to_df, axis=1)
df_2 = pd.concat(df_1.to_list(), ignore_index=True)
df_2.head()
# Out:
#                                           experiment variant_id  user_id  \
# 0                 searchbackend/recommended-products       6158       59
# 1  mclics/ads-adsearch-boost-incremental-desktop-mla       3809       59
# 2                        searchbackend/cbt-antiboost       6333       59
# 3                                search/back-filters       5059       59
# 4                            filters/sort-by-ranking       6972       59
#
#   event_name  item_id                     timestamp  \
# 0     SEARCH      NaN  2021-08-02T09:28:32.820-0400
# 1     SEARCH      NaN  2021-08-02T09:28:32.820-0400
# 2     SEARCH      NaN  2021-08-02T09:28:32.820-0400
# 3     SEARCH      NaN  2021-08-02T09:28:32.820-0400
# 4     SEARCH      NaN  2021-08-02T09:28:32.820-0400
#
#                           datetime        date site
# 0 2021-08-02 09:28:32.820000-04:00  2021-08-02  MLA
# 1 2021-08-02 09:28:32.820000-04:00  2021-08-02  MLA
# 2 2021-08-02 09:28:32.820000-04:00  2021-08-02  MLA
# 3 2021-08-02 09:28:32.820000-04:00  2021-08-02  MLA
# 4 2021-08-02 09:28:32.820000-04:00  2021-08-02  MLA

# %% [markdown]
# Ahora, nuevamente tomando el articulo de referencia, vamos a separar la columna "experiment" en dos con el separador "/" para distinguir entre el "path" y el experimento como tal:

# %%
# Aplicamos la función split a la columna "experiment_name" y expandirla en nuevas columnas
nuevas_columnas = df_2["experiment"].str.split('/', expand=True)

# Asignamos nombres a las nuevas columnas
nuevas_columnas = nuevas_columnas.rename(columns={0: "path", 1: "experiment_name"})

# Unimos las nuevas columnas al DataFrame original
df_3 = pd.concat([df_2, nuevas_columnas], axis=1)

# Reordenamos el dataframe
df_3 = df_3[['user_id', 'event_name', 'item_id', 'timestamp', 'datetime', 'date', 'site', 'experiment', 'path', 'experiment_name', 'variant_id']]
df_3.head()
# Out:
#    user_id event_name  item_id                     timestamp  \
# 0       59     SEARCH      NaN  2021-08-02T09:28:32.820-0400
# 1       59     SEARCH      NaN  2021-08-02T09:28:32.820-0400
# 2       59     SEARCH      NaN  2021-08-02T09:28:32.820-0400
# 3       59     SEARCH      NaN  2021-08-02T09:28:32.820-0400
# 4       59     SEARCH      NaN  2021-08-02T09:28:32.820-0400
#
#                           datetime        date site  \
# 0 2021-08-02 09:28:32.820000-04:00  2021-08-02  MLA
# 1 2021-08-02 09:28:32.820000-04:00  2021-08-02  MLA
# 2 2021-08-02 09:28:32.820000-04:00  2021-08-02  MLA
# 3 2021-08-02 09:28:32.820000-04:00  2021-08-02  MLA
# 4 2021-08-02 09:28:32.820000-04:00  2021-08-02  MLA
#
#                                           experiment           path  \
# 0                 searchbackend/recommended-products  searchbackend
# 1  mclics/ads-adsearch-boost-incremental-desktop-mla         mclics
# 2                        searchbackend/cbt-antiboost  searchbackend
# 3                                search/back-filters         search
# 4                            filters/sort-by-ranking        filters
#
#                               experiment_name variant_id
# 0                        recommended-products       6158
# 1  ads-adsearch-boost-incremental-desktop-mla       3809
# 2                               cbt-antiboost       6333
# 3                                back-filters       5059
# 4                             sort-by-ranking       6972

# %% [markdown]
# Listo lo anterior, debemos crear una variable binaria de 1s y 0s que nos permita identificar si el experimento termino en compra o no (conversion). Para ello, filtramos inicialmente el dataframe anterior, solo con los clientes que hicieron compra y vamos a asignar el valor de 1 a cada registro:

# %%
# Presentamos la información de cuyos usuarios terminaron el compra al final de la "cadena de navegación" y agregamos una columna con 1s para estos usuarios que terminaron su "cadena de navegacion" en compra
df_buy_0 = df_3[df_3['event_name']=='BUY']
df_buy_0 = df_buy_0.assign(conversion_buy=1)
df_buy_0.head()
# Out:
#       user_id event_name      item_id                     timestamp  \
# 1049      311        BUY   79821609.0  2021-08-02T08:54:38.662-0400
# 1050      311        BUY   79821609.0  2021-08-02T08:54:38.662-0400
# 1901      466        BUY  789004239.0  2021-08-02T20:08:19.990-0400
# 1967      466        BUY  789004239.0  2021-08-02T20:14:41.474-0400
# 1968      466        BUY  789004239.0  2021-08-02T20:14:41.474-0400
#
#                              datetime        date site  \
# 1049 2021-08-02 08:54:38.662000-04:00  2021-08-02  MLA
# 1050 2021-08-02 08:54:38.662000-04:00  2021-08-02  MLA
# 1901 2021-08-02 20:08:19.990000-04:00  2021-08-02  MLA
# 1967 2021-08-02 20:14:41.474000-04:00  2021-08-02  MLA
# 1968 2021-08-02 20:14:41.474000-04:00  2021-08-02  MLA
#
#                   experiment        path experiment_name variant_id  \
# 1049   buyingflow/user-track  buyingflow      user-track       6796
# 1050  buyingflow/address_hub  buyingflow     address_hub       3574
# 1901   buyingflow/user-track  buyingflow      user-track       6796
# 1967   buyingflow/user-track  buyingflow      user-track       6796
# 1968  buyingflow/address_hub  buyingflow     address_hub       3574
#
#       conversion_buy
# 1049               1
# 1050               1
# 1901               1
# 1967               1
# 1968               1

# %% [markdown]
# Como podemos observar, algunos clientes se repiten, esto porque en la etapa de compra ("BUY") tuvieron mas de un experimento. Sin embargo, podemos identificar que corresponden a un mismo "item_id", con lo cual, podemos descartar las demas variables y crear un dataframe más sencillo que con los elementos que necesitaremos de llave para cruzar, estos son "user_id" e "item_id" junto a la marca de conversion:

# %%
# Arreglamos los datos que necesitaremos para hacer el join/merge mas adelante y saber si la "cadena de navegacón" tuvo conversión o no a compra
df_buy_1 = df_buy_0[['user_id', 'item_id', 'conversion_buy']].drop_duplicates()
df_buy_1
# Out:
#          user_id      item_id  conversion_buy
# 1049         311   79821609.0               1
# 1901         466  789004239.0               1
# 3438         773  380896406.0               1
# 5280        1512  417500229.0               1
# 6800        1683  873085588.0               1
# ...          ...          ...             ...
# 1333440  9942302  566557629.0               1
# 1333644  9944412  417755019.0               1
# 1333936  9955631  440867658.0               1
# 1334400  9963531  393529429.0               1
# 1335548  9975941  356305667.0               1
#
# [934 rows x 3 columns]

# %% [markdown]
# Ahora lo que sigue, es cruzar los dataframes, de tal modo que a cada "user_id", le peguemos si para ese "item_id" su "cadena de navegacion" terminó en compra o no. Con esto lo que hacemos es mapear toda la "cadena de navegación" y determinar si esa cadena termino en compra, independiente del momento de tiempo que se haya dado:

# %%
# Hacemos la unión de las 2 tablas para saber cuales eventos terminaron en compra y cuales no con una variable binaria de 1s y 0s
df_4 = pd.merge(df_3, df_buy_1, on=['user_id','item_id'], how='left')
df_4['conversion_buy'] = df_4['conversion_buy'].fillna(0)
df_4['conversion_buy'] = df_4['conversion_buy'].astype(int)
df_4.head()
# Out:
#    user_id event_name  item_id                     timestamp  \
# 0       59     SEARCH      NaN  2021-08-02T09:28:32.820-0400
# 1       59     SEARCH      NaN  2021-08-02T09:28:32.820-0400
# 2       59     SEARCH      NaN  2021-08-02T09:28:32.820-0400
# 3       59     SEARCH      NaN  2021-08-02T09:28:32.820-0400
# 4       59     SEARCH      NaN  2021-08-02T09:28:32.820-0400
#
#                           datetime        date site  \
# 0 2021-08-02 09:28:32.820000-04:00  2021-08-02  MLA
# 1 2021-08-02 09:28:32.820000-04:00  2021-08-02  MLA
# 2 2021-08-02 09:28:32.820000-04:00  2021-08-02  MLA
# 3 2021-08-02 09:28:32.820000-04:00  2021-08-02  MLA
# 4 2021-08-02 09:28:32.820000-04:00  2021-08-02  MLA
#
#                                           experiment           path  \
# 0                 searchbackend/recommended-products  searchbackend
# 1  mclics/ads-adsearch-boost-incremental-desktop-mla         mclics
# 2                        searchbackend/cbt-antiboost  searchbackend
# 3                                search/back-filters         search
# 4                            filters/sort-by-ranking        filters
#
#                               experiment_name variant_id  conversion_buy
# 0                        recommended-products       6158               0
# 1  ads-adsearch-boost-incremental-desktop-mla       3809               0
# 2                               cbt-antiboost       6333               0
# 3                                back-filters       5059               0
# 4                             sort-by-ranking       6972               0

# %% [markdown]
# Debemos seguir revisando que los datos sean correctos para utilizarlos y que permitan sacar conclusiones confiables. Ahora vamos a filtrar los datos para un cliente en particular que realizó una compra y ver su "cadena de navegación":

# %%
# Tomamos uno de los usuarios que termino en compra para ver su "cadena de navegación"
df_4[(df_4['user_id']==466) & (df_4['item_id']==789004239.0)]
# Out:
#       user_id  event_name      item_id                     timestamp  \
# 1826      466     PRODUCT  789004239.0  2021-08-02T19:45:44.269-0400
# 1827      466     PRODUCT  789004239.0  2021-08-02T19:45:44.269-0400
# 1828      466     PRODUCT  789004239.0  2021-08-02T19:45:44.269-0400
# 1829      466     PRODUCT  789004239.0  2021-08-02T19:45:44.269-0400
# 1830      466     PRODUCT  789004239.0  2021-08-02T19:45:44.269-0400
# 1831      466     PRODUCT  789004239.0  2021-08-02T19:45:44.269-0400
# 1832      466     PRODUCT  789004239.0  2021-08-02T19:45:44.269-0400
# 1894      466  CHECKOUT_1  789004239.0  2021-08-02T20:03:38.246-0400
# 1895      466  CHECKOUT_2  789004239.0  2021-08-02T20:03:54.376-0400
# 1896      466  CHECKOUT_2  789004239.0  2021-08-02T20:03:54.376-0400
# 1897      466  CHECKOUT_2  789004239.0  2021-08-02T20:05:58.453-0400
# 1898      466  CHECKOUT_2  789004239.0  2021-08-02T20:07:10.185-0400
# 1899      466  CHECKOUT_3  789004239.0  2021-08-02T20:07:29.148-0400
# 1900      466  CHECKOUT_3  789004239.0  2021-08-02T20:07:29.148-0400
# 1901      466         BUY  789004239.0  2021-08-02T20:08:19.990-0400
# 1955      466  CHECKOUT_1  789004239.0  2021-08-02T20:10:10.450-0400
# 1956      466  CHECKOUT_1  789004239.0  2021-08-02T20:10:10.450-0400
# 1957      466  CHECKOUT_1  789004239.0  2021-08-02T20:11:20.638-0400
# 1958      466  CHECKOUT_1  789004239.0  2021-08-02T20:11:20.638-0400
# 1959      466  CHECKOUT_2  789004239.0  2021-08-02T20:12:25.512-0400
# 1960      466  CHECKOUT_2  789004239.0  2021-08-02T20:12:25.512-0400
# 1961      466  CHECKOUT_1  789004239.0  2021-08-02T20:12:57.128-0400
# 1962      466  CHECKOUT_1  789004239.0  2021-08-02T20:12:57.128-0400
# 1963      466  CHECKOUT_2  789004239.0  2021-08-02T20:13:02.610-0400
# 1964      466  CHECKOUT_2  789004239.0  2021-08-02T20:13:02.610-0400
# 1965      466  CHECKOUT_3  789004239.0  2021-08-02T20:14:27.388-0400
# 1966      466  CHECKOUT_3  789004239.0  2021-08-02T20:14:27.388-0400
# 1967      466         BUY  789004239.0  2021-08-02T20:14:41.474-0400
# 1968      466         BUY  789004239.0  2021-08-02T20:14:41.474-0400
#
#                              datetime        date site  \
# 1826 2021-08-02 19:45:44.269000-04:00  2021-08-02  MLA
# 1827 2021-08-02 19:45:44.269000-04:00  2021-08-02  MLA
# 1828 2021-08-02 19:45:44.269000-04:00  2021-08-02  MLA
# 1829 2021-08-02 19:45:44.269000-04:00  2021-08-02  MLA
# 1830 2021-08-02 19:45:44.269000-04:00  2021-08-02  MLA
# 1831 2021-08-02 19:45:44.269000-04:00  2021-08-02  MLA
# 1832 2021-08-02 19:45:44.269000-04:00  2021-08-02  MLA
# 1894 2021-08-02 20:03:38.246000-04:00  2021-08-02  MLA
# 1895 2021-08-02 20:03:54.376000-04:00  2021-08-02  MLA
# 1896 2021-08-02 20:03:54.376000-04:00  2021-08-02  MLA
# 1897 2021-08-02 20:05:58.453000-04:00  2021-08-02  MLA
# 1898 2021-08-02 20:07:10.185000-04:00  2021-08-02  MLA
# 1899 2021-08-02 20:07:29.148000-04:00  2021-08-02  MLA
# 1900 2021-08-02 20:07:29.148000-04:00  2021-08-02  MLA
# 1901 2021-08-02 20:08:19.990000-04:00  2021-08-02  MLA
# 1955 2021-08-02 20:10:10.450000-04:00  2021-08-02  MLA
# 1956 2021-08-02 20:10:10.450000-04:00  2021-08-02  MLA
# 1957 2021-08-02 20:11:20.638000-04:00  2021-08-02  MLA
# 1958 2021-08-02 20:11:20.638000-04:00  2021-08-02  MLA
# 1959 2021-08-02 20:12:25.512000-04:00  2021-08-02  MLA
# 1960 2021-08-02 20:12:25.512000-04:00  2021-08-02  MLA
# 1961 2021-08-02 20:12:57.128000-04:00  2021-08-02  MLA
# 1962 2021-08-02 20:12:57.128000-04:00  2021-08-02  MLA
# 1963 2021-08-02 20:13:02.610000-04:00  2021-08-02  MLA
# 1964 2021-08-02 20:13:02.610000-04:00  2021-08-02  MLA
# 1965 2021-08-02 20:14:27.388000-04:00  2021-08-02  MLA
# 1966 2021-08-02 20:14:27.388000-04:00  2021-08-02  MLA
# 1967 2021-08-02 20:14:41.474000-04:00  2021-08-02  MLA
# 1968 2021-08-02 20:14:41.474000-04:00  2021-08-02  MLA
#
#                                           experiment                  path  \
# 1826                           search/remove-ecn-tag                search
# 1827                         vip/showV2V3BoxMessages                   vip
# 1828                            cookiesConsentBanner  cookiesConsentBanner
# 1829  vip/shippingCalculatorMigrationModalExperiment                   vip
# 1830                 vip/carousel-v2p-above-the-fold                   vip
# 1831                pdp/viewItemPageMigrationReturns                   pdp
# 1832                         vip/seller-with-tooltip                   vip
# 1894                           buyingflow/user-track            buyingflow
# 1895                           buyingflow/user-track            buyingflow
# 1896                          buyingflow/address_hub            buyingflow
# 1897                           buyingflow/user-track            buyingflow
# 1898                           buyingflow/user-track            buyingflow
# 1899                           buyingflow/user-track            buyingflow
# 1900                          buyingflow/address_hub            buyingflow
# 1901                           buyingflow/user-track            buyingflow
# 1955                           buyingflow/user-track            buyingflow
# 1956                            buyingflow/escWebMLA            buyingflow
# 1957                           buyingflow/user-track            buyingflow
# 1958                            buyingflow/escWebMLA            buyingflow
# 1959                           buyingflow/user-track            buyingflow
# 1960                          buyingflow/address_hub            buyingflow
# 1961                           buyingflow/user-track            buyingflow
# 1962                            buyingflow/escWebMLA            buyingflow
# 1963                           buyingflow/user-track            buyingflow
# 1964                          buyingflow/address_hub            buyingflow
# 1965                           buyingflow/user-track            buyingflow
# 1966                          buyingflow/address_hub            buyingflow
# 1967                           buyingflow/user-track            buyingflow
# 1968                          buyingflow/address_hub            buyingflow
#
#                                  experiment_name variant_id  conversion_buy
# 1826                              remove-ecn-tag       4954               1
# 1827                         showV2V3BoxMessages       6430               1
# 1828                                        None    DEFAULT               1
# 1829  shippingCalculatorMigrationModalExperiment       6551               1
# 1830                 carousel-v2p-above-the-fold       6786               1
# 1831                viewItemPageMigrationReturns       5208               1
# 1832                         seller-with-tooltip       4692               1
# 1894                                  user-track       6796               1
# 1895                                  user-track       6796               1
# 1896                                 address_hub       3574               1
# 1897                                  user-track       6796               1
# 1898                                  user-track       6796               1
# 1899                                  user-track       6796               1
# 1900                                 address_hub       3574               1
# 1901                                  user-track       6796               1
# 1955                                  user-track       6796               1
# 1956                                   escWebMLA       2874               1
# 1957                                  user-track       6796               1
# 1958                                   escWebMLA       2874               1
# 1959                                  user-track       6796               1
# 1960                                 address_hub       3574               1
# 1961                                  user-track       6796               1
# 1962                                   escWebMLA       2874               1
# 1963                                  user-track       6796               1
# 1964                                 address_hub       3574               1
# 1965                                  user-track       6796               1
# 1966                                 address_hub       3574               1
# 1967                                  user-track       6796               1
# 1968                                 address_hub       3574               1

# %% [markdown]
# En la salida anterior vemos un posible error que puede traer problemas o duplicidad de los datos. Por ejemplo, el experimento **buyingflow/user-track=6796** se repite varias veces en diferentes eventos, como son **CHECKOUT_1**, **CHECKOUT_1**, **CHECKOUT_1** y **BUY**.
#
# Para que esto no nos cause problemas vamos a quedarnos con la minima fecha a la que el usuario se enfrento a ese experimento, de tal modo que solo nos va a aparecer una vez dicho experimento por "cadena de navegación" y sera el primero al que el usuario se enfrentó:

# %%
# En el paso anterior hemos visto que algunos usuarios se repien con la misma información, para ello nos vamos a quedar con la minima fecha, que seria el primer momento en que el ususario se enfrento al experimento
df_4 = df_4.groupby(['user_id', 'item_id', 'date','site', 'experiment', 'path', 'experiment_name', 'variant_id', 'conversion_buy'])['datetime'].min().reset_index()
df_4.head()
# Out:
#    user_id      item_id        date site  \
# 0       59  108629748.0  2021-08-02  MLA
# 1       59  108629748.0  2021-08-02  MLA
# 2       59  108629748.0  2021-08-02  MLA
# 3       59  108629748.0  2021-08-02  MLA
# 4       59  108629748.0  2021-08-02  MLA
#
#                                       experiment    path  \
# 0  pdp/viewItemPageMigrationDesktopReviewsNoTabs     pdp
# 1               pdp/viewItemPageMigrationReturns     pdp
# 2                          search/remove-ecn-tag  search
# 3                vip/carousel-v2p-above-the-fold     vip
# 4                        vip/seller-with-tooltip     vip
#
#                              experiment_name variant_id  conversion_buy  \
# 0  viewItemPageMigrationDesktopReviewsNoTabs       4856               0
# 1               viewItemPageMigrationReturns       5208               0
# 2                             remove-ecn-tag       4954               0
# 3                carousel-v2p-above-the-fold       6787               0
# 4                        seller-with-tooltip       4692               0
#
#                           datetime
# 0 2021-08-02 10:03:07.722000-04:00
# 1 2021-08-02 10:03:07.722000-04:00
# 2 2021-08-02 10:03:07.722000-04:00
# 3 2021-08-02 10:03:07.722000-04:00
# 4 2021-08-02 10:03:07.722000-04:00

# %% [markdown]
# Volvemos a validar el usuario e item para validar que cada experimento aparezca una sola vez:

# %%
# Validamos el mismo caso donde observamos que el ususario se repetia varias veces por ejemplo en el experimento "user-track = 6796" ahora aparece una sola vez por experimento
df_4[(df_4['user_id']==466) & (df_4['item_id']==789004239.0)]
# Out:
#      user_id      item_id        date site  \
# 324      466  789004239.0  2021-08-02  MLA
# 325      466  789004239.0  2021-08-02  MLA
# 326      466  789004239.0  2021-08-02  MLA
# 327      466  789004239.0  2021-08-02  MLA
# 328      466  789004239.0  2021-08-02  MLA
# 329      466  789004239.0  2021-08-02  MLA
# 330      466  789004239.0  2021-08-02  MLA
# 331      466  789004239.0  2021-08-02  MLA
# 332      466  789004239.0  2021-08-02  MLA
#
#                                          experiment        path  \
# 324                          buyingflow/address_hub  buyingflow
# 325                            buyingflow/escWebMLA  buyingflow
# 326                           buyingflow/user-track  buyingflow
# 327                pdp/viewItemPageMigrationReturns         pdp
# 328                           search/remove-ecn-tag      search
# 329                 vip/carousel-v2p-above-the-fold         vip
# 330                         vip/seller-with-tooltip         vip
# 331  vip/shippingCalculatorMigrationModalExperiment         vip
# 332                         vip/showV2V3BoxMessages         vip
#
#                                 experiment_name variant_id  conversion_buy  \
# 324                                 address_hub       3574               1
# 325                                   escWebMLA       2874               1
# 326                                  user-track       6796               1
# 327                viewItemPageMigrationReturns       5208               1
# 328                              remove-ecn-tag       4954               1
# 329                 carousel-v2p-above-the-fold       6786               1
# 330                         seller-with-tooltip       4692               1
# 331  shippingCalculatorMigrationModalExperiment       6551               1
# 332                         showV2V3BoxMessages       6430               1
#
#                             datetime
# 324 2021-08-02 20:03:54.376000-04:00
# 325 2021-08-02 20:10:10.450000-04:00
# 326 2021-08-02 20:03:38.246000-04:00
# 327 2021-08-02 19:45:44.269000-04:00
# 328 2021-08-02 19:45:44.269000-04:00
# 329 2021-08-02 19:45:44.269000-04:00
# 330 2021-08-02 19:45:44.269000-04:00
# 331 2021-08-02 19:45:44.269000-04:00
# 332 2021-08-02 19:45:44.269000-04:00

# %% [markdown]
# **Enhorabuena**, el dataframe anterior tiene toda la información como la necesitamos para poder trabajarla.

# %%
# Resumen información del dataframe final
print("Info dataset:")
print(df_4.info())
print('\n')
print("Valores unicos por variable:")
print(df_4.nunique())
# Out:
# Info dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231517 entries, 0 to 231516
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   user_id          231517 non-null  int64
#  1   item_id          231517 non-null  float64
#  2   date             231517 non-null  object
#  3   site             231517 non-null  object
#  4   experiment       231517 non-null  object
#  5   path             231517 non-null  object
#  6   experiment_name  231517 non-null  object
#  7   variant_id       231517 non-null  object
#  8   conversion_buy   231517 non-null  int64
#  9   datetime         231517 non-null  datetime64[ns, pytz.FixedOffset(-240)]
# dtypes: datetime64[ns, pytz.FixedOffset(-240)](1), float64(1), int64(2), object(6)
# memory usage: 17.7+ MB
# None
#
#
# Valores unicos por variable:
# user_id             6298
# item_id            41062
# date                   2
# site                   1
# experiment            23
# path                   7
# experiment_name       23
# variant_id            28
# conversion_buy         2
# datetime           45311
# dtype: int64

# %% [markdown]
# Nuevamente siguiendo el [articulo de referencia](https://medium.com/mercadolibre-tech/a-b-testing-meli-3a5ad2b4594d), vamos a crear un dataframe de resumen contando por fecha, la cantidad de ususarios que se sometieron a cada experimento y sus posibles variantes. Ademas, se agrega la suma de usuarios cuya "cadena de navegación" terminó en compra y se calcula la tasa de conversión como la cantidad de compras sobre el total de ususarios que vieron el experimento:

# %%
# Vamos a presentar los resultados finales de forma similar al articulo de referencia: https://medium.com/mercadolibre-tech/a-b-testing-meli-3a5ad2b4594d

df_5 = df_4.groupby(['date', 'experiment_name', 'variant_id']) \
           .agg({'user_id': 'count', 'conversion_buy': 'sum'}) \
           .reset_index()
df_5 = df_5.rename(columns={"user_id": "users"})
df_5['conversion_rate'] = df_5['conversion_buy']/df_5['users']
df_5['conversion_rate_%'] = df_5['conversion_rate'] .apply(lambda x: '{:.2f}%'.format(x*100))
df_5 = df_5.sort_values(['date','experiment_name', 'conversion_rate_%', ], ascending = [True, True, False], ignore_index=True)
df_5
# Out:
#           date                            experiment_name variant_id  users  \
# 0   2021-08-01                        HideTransitionModal       6646      2
# 1   2021-08-01                        HideTransitionModal       6647      4
# 2   2021-08-01                        HideTransitionModal       6993      7
# 3   2021-08-01                        HideTransitionModal    DEFAULT     12
# 4   2021-08-01                                address_hub       3574    225
# ..         ...                                        ...        ...    ...
# 66  2021-08-02         viewItemPageMigrationDesktopRESDev       6861      5
# 67  2021-08-02  viewItemPageMigrationDesktopReviewsNoTabs       4856  11455
# 68  2021-08-02  viewItemPageMigrationDesktopReviewsNoTabs    DEFAULT      6
# 69  2021-08-02               viewItemPageMigrationReturns       5208  20025
# 70  2021-08-02               viewItemPageMigrationReturns    DEFAULT     19
#
#     conversion_buy  conversion_rate conversion_rate_%
# 0                0         0.000000             0.00%
# 1                0         0.000000             0.00%
# 2                0         0.000000             0.00%
# 3                0         0.000000             0.00%
# 4              171         0.760000            76.00%
# ..             ...              ...               ...
# 66               0         0.000000             0.00%
# 67             346         0.030205             3.02%
# 68               0         0.000000             0.00%
# 69             466         0.023271             2.33%
# 70               0         0.000000             0.00%
#
# [71 rows x 7 columns]

# %% [markdown]
# Ahora podemos filtrar la información para ver solamente aquellos experimentos que hayan tenido una conversión o que hayan terminado en compra. Esto podriamos hacerlo de dos formas diferentes:

# %% [markdown]
# ### **Opción 1:**
# Filtrar de todos los posibles experimentos, aquellos que hayan tenido mas de una variante para poder comparar.

# %%
# Agrupamos los datos por experimento y fecha para contar el número de variantes
variant_counts_1 = df_5.groupby(['experiment_name', 'date'])['variant_id'].nunique()

# Filtramos los datos para aquellos experimentos con más de una variante 
df_6 = df_5.loc[(df_5['experiment_name'].isin(variant_counts_1[variant_counts_1 > 1].index.get_level_values(0)))].reset_index(drop=True)

# Mostramos el dataframe filtrado
df_6
# Out:
#           date                             experiment_name variant_id  users  \
# 0   2021-08-01                         HideTransitionModal       6646      2
# 1   2021-08-01                         HideTransitionModal       6647      4
# 2   2021-08-01                         HideTransitionModal       6993      7
# 3   2021-08-01                         HideTransitionModal    DEFAULT     12
# 4   2021-08-01                 carousel-v2p-above-the-fold       6787   3337
# 5   2021-08-01                 carousel-v2p-above-the-fold       6786   3400
# 6   2021-08-01                 carousel-v2p-above-the-fold    DEFAULT      8
# 7   2021-08-01                              remove-ecn-tag       4954   6042
# 8   2021-08-01                              remove-ecn-tag    DEFAULT      8
# 9   2021-08-01                                   sa-on-vip       6696    727
# 10  2021-08-01                                   sa-on-vip       6695    672
# 11  2021-08-01  shippingCalculatorMigrationModalExperiment       6551   7363
# 12  2021-08-01  shippingCalculatorMigrationModalExperiment    DEFAULT      9
# 13  2021-08-01                         showV2V3BoxMessages       6430   8978
# 14  2021-08-01                         showV2V3BoxMessages    DEFAULT     12
# 15  2021-08-01      viewItemPageMigrationDesktopHirableSRV       7174      3
# 16  2021-08-01      viewItemPageMigrationDesktopHirableSRV       7175      4
# 17  2021-08-01     viewItemPageMigrationDesktopQuotableSRV       7178     11
# 18  2021-08-01     viewItemPageMigrationDesktopQuotableSRV       7179      2
# 19  2021-08-01   viewItemPageMigrationDesktopReviewsNoTabs       4856   3330
# 20  2021-08-01   viewItemPageMigrationDesktopReviewsNoTabs    DEFAULT      5
# 21  2021-08-01                viewItemPageMigrationReturns       5208   5151
# 22  2021-08-01                viewItemPageMigrationReturns    DEFAULT      7
# 23  2021-08-02                         HideTransitionModal       6993     28
# 24  2021-08-02                         HideTransitionModal       6646     32
# 25  2021-08-02                         HideTransitionModal       6647     49
# 26  2021-08-02                         HideTransitionModal    DEFAULT     32
# 27  2021-08-02                 carousel-v2p-above-the-fold       6787  11754
# 28  2021-08-02                 carousel-v2p-above-the-fold       6786  12748
# 29  2021-08-02                 carousel-v2p-above-the-fold    DEFAULT     26
# 30  2021-08-02                              remove-ecn-tag       4954  22429
# 31  2021-08-02                              remove-ecn-tag    DEFAULT     24
# 32  2021-08-02                                   sa-on-vip       6696   2128
# 33  2021-08-02                                   sa-on-vip       6695   2318
# 34  2021-08-02  shippingCalculatorMigrationModalExperiment       6551  26707
# 35  2021-08-02  shippingCalculatorMigrationModalExperiment    DEFAULT     24
# 36  2021-08-02                         showV2V3BoxMessages       6430  31645
# 37  2021-08-02                         showV2V3BoxMessages    DEFAULT     32
# 38  2021-08-02      viewItemPageMigrationDesktopHirableSRV       7174     50
# 39  2021-08-02      viewItemPageMigrationDesktopHirableSRV       7175      4
# 40  2021-08-02     viewItemPageMigrationDesktopQuotableSRV       7178      6
# 41  2021-08-02     viewItemPageMigrationDesktopQuotableSRV       7179     40
# 42  2021-08-02   viewItemPageMigrationDesktopReviewsNoTabs       4856  11455
# 43  2021-08-02   viewItemPageMigrationDesktopReviewsNoTabs    DEFAULT      6
# 44  2021-08-02                viewItemPageMigrationReturns       5208  20025
# 45  2021-08-02                viewItemPageMigrationReturns    DEFAULT     19
#
#     conversion_buy  conversion_rate conversion_rate_%
# 0                0         0.000000             0.00%
# 1                0         0.000000             0.00%
# 2                0         0.000000             0.00%
# 3                0         0.000000             0.00%
# 4               71         0.021277             2.13%
# 5               68         0.020000             2.00%
# 6                0         0.000000             0.00%
# 7              127         0.021020             2.10%
# 8                0         0.000000             0.00%
# 9               15         0.020633             2.06%
# 10               8         0.011905             1.19%
# 11             139         0.018878             1.89%
# 12               0         0.000000             0.00%
# 13             154         0.017153             1.72%
# 14               0         0.000000             0.00%
# 15               0         0.000000             0.00%
# 16               0         0.000000             0.00%
# 17               0         0.000000             0.00%
# 18               0         0.000000             0.00%
# 19              83         0.024925             2.49%
# 20               0         0.000000             0.00%
# 21              98         0.019025             1.90%
# 22               0         0.000000             0.00%
# 23               1         0.035714             3.57%
# 24               1         0.031250             3.12%
# 25               0         0.000000             0.00%
# 26               0         0.000000             0.00%
# 27             298         0.025353             2.54%
# 28             309         0.024239             2.42%
# 29               0         0.000000             0.00%
# 30             555         0.024745             2.47%
# 31               0         0.000000             0.00%
# 32              56         0.026316             2.63%
# 33              41         0.017688             1.77%
# 34             618         0.023140             2.31%
# 35               0         0.000000             0.00%
# 36             667         0.021078             2.11%
# 37               0         0.000000             0.00%
# 38               0         0.000000             0.00%
# 39               0         0.000000             0.00%
# 40               0         0.000000             0.00%
# 41               0         0.000000             0.00%
# 42             346         0.030205             3.02%
# 43               0         0.000000             0.00%
# 44             466         0.023271             2.33%
# 45               0         0.000000             0.00%

# %% [markdown]
# ### **Opción 2:**
# Filtrar todos de todos los posibles experimentos, aquellos que hayan llegado a compra (conversion=1) y luego filtrar de los que llegaron a comprar, los que tengan mas de una variante para poder comparar.

# %%
# Podemos hacerlo de otra forma y es, filtrar primero aquellos experimentps que hayan terminado en compra y luego quedarnos con los que hayan tenido mas de 1 variante para comparar

df_7 = df_5[(df_5['conversion_buy']!=0)]

# Agrupamos los datos por experimento y fecha y contar el número de variantes
variant_counts_2 = df_7.groupby(['experiment_name', 'date'])['variant_id'].nunique()

# FiltraMmos los datos para aquellos experimentos con más de una variante 
df_7 = df_7.loc[(df_7['experiment_name'].isin(variant_counts_2[variant_counts_2 > 1].index.get_level_values(0)))].reset_index(drop=True)

# Mostramos el DataFrame filtrado
df_7
# Out:
#          date              experiment_name variant_id  users  conversion_buy  \
# 0  2021-08-01  carousel-v2p-above-the-fold       6787   3337              71
# 1  2021-08-01  carousel-v2p-above-the-fold       6786   3400              68
# 2  2021-08-01                    sa-on-vip       6696    727              15
# 3  2021-08-01                    sa-on-vip       6695    672               8
# 4  2021-08-02          HideTransitionModal       6993     28               1
# 5  2021-08-02          HideTransitionModal       6646     32               1
# 6  2021-08-02  carousel-v2p-above-the-fold       6787  11754             298
# 7  2021-08-02  carousel-v2p-above-the-fold       6786  12748             309
# 8  2021-08-02                    sa-on-vip       6696   2128              56
# 9  2021-08-02                    sa-on-vip       6695   2318              41
#
#    conversion_rate conversion_rate_%
# 0         0.021277             2.13%
# 1         0.020000             2.00%
# 2         0.020633             2.06%
# 3         0.011905             1.19%
# 4         0.035714             3.57%
# 5         0.031250             3.12%
# 6         0.025353             2.54%
# 7         0.024239             2.42%
# 8         0.026316             2.63%
# 9         0.017688             1.77%

# %% [markdown]
# En el resultado anterior podemos ver 3 diferentes experimentos que se aplicaron en días diferentes cada uno con dos posibles variantes. Allí, se presenta la cantidad de usuarios que vieron cada experiment y cuantos de los que lo vieron luego realizaron una compra (conversion_rate).

# %% [markdown]
# Como parte de la revisión de los datos, para evaluar que sean correctos para sacar conclusiones, vamos a revisar la cantidad de posibles variantes para cada experimento:

# %%
# Agrupar por experimento y variante contar el número de veces que aparece cada variante
variantes_por_experimento = df_4.groupby('experiment_name')['variant_id'].value_counts()
variantes_por_experimento
# Out:
# experiment_name                             variant_id
# HideTransitionModal                         6647             53
#                                             DEFAULT          44
#                                             6993             35
#                                             6646             34
# address_hub                                 3574           1171
# assetsCdnDomainMLA                          DEFAULT          25
# carousel-v2p-above-the-fold                 6786          16148
#                                             6787          15091
#                                             DEFAULT          34
# classiWordingFree                           2826             25
# compatibilityWidget                         5539             21
# cpgShowOnlyAddToCart                        6690             98
# escWebMLA                                   2874           1332
# remove-ecn-tag                              4954          28471
#                                             DEFAULT          32
# sa-on-vip                                   6695           2990
#                                             6696           2855
# secure_card                                 4612             25
# seller-with-tooltip                         4692          38530
# servicesQuoteUnification                    DEFAULT          25
# shippingCalculatorMigrationModalExperiment  6551          34070
#                                             DEFAULT          33
# showV2V3BoxMessages                         6430          40623
#                                             DEFAULT          44
# tendency-landing-enabled-MLA                6980           6384
# user-track                                  6796           1446
# viewItemPageMigrationDesktopHirableSRV      7174             53
#                                             7175              8
# viewItemPageMigrationDesktopQuotableSRV     7179             42
#                                             7178             17
# viewItemPageMigrationDesktopRES             5941           1755
# viewItemPageMigrationDesktopRESDev          6861              5
# viewItemPageMigrationDesktopReviewsNoTabs   4856          14785
#                                             DEFAULT          11
# viewItemPageMigrationReturns                5208          25176
#                                             DEFAULT          26
# Name: variant_id, dtype: int64

# %% [markdown]
# De igual forma es importante validar si alguna variante se repite para más de un experimento, que por suerte no es el caso:

# %%
# Agrupar por variante y experimento y contar el número de veces que aparece cada experimento
experimentos_por_variante = df_4.groupby('variant_id')['experiment_name'].value_counts()
experimentos_por_variante
# Out:
# variant_id  experiment_name
# 2826        classiWordingFree                                25
# 2874        escWebMLA                                      1332
# 3574        address_hub                                    1171
# 4612        secure_card                                      25
# 4692        seller-with-tooltip                           38530
# 4856        viewItemPageMigrationDesktopReviewsNoTabs     14785
# 4954        remove-ecn-tag                                28471
# 5208        viewItemPageMigrationReturns                  25176
# 5539        compatibilityWidget                              21
# 5941        viewItemPageMigrationDesktopRES                1755
# 6430        showV2V3BoxMessages                           40623
# 6551        shippingCalculatorMigrationModalExperiment    34070
# 6646        HideTransitionModal                              34
# 6647        HideTransitionModal                              53
# 6690        cpgShowOnlyAddToCart                             98
# 6695        sa-on-vip                                      2990
# 6696        sa-on-vip                                      2855
# 6786        carousel-v2p-above-the-fold                   16148
# 6787        carousel-v2p-above-the-fold                   15091
# 6796        user-track                                     1446
# 6861        viewItemPageMigrationDesktopRESDev                5
# 6980        tendency-landing-enabled-MLA                   6384
# 6993        HideTransitionModal                              35
# 7174        viewItemPageMigrationDesktopHirableSRV           53
# 7175        viewItemPageMigrationDesktopHirableSRV            8
# 7178        viewItemPageMigrationDesktopQuotableSRV          17
# 7179        viewItemPageMigrationDesktopQuotableSRV          42
# DEFAULT     HideTransitionModal                              44
#             showV2V3BoxMessages                              44
#             carousel-v2p-above-the-fold                      34
#             shippingCalculatorMigrationModalExperiment       33
#             remove-ecn-tag                                   32
#             viewItemPageMigrationReturns                     26
#             assetsCdnDomainMLA                               25
#             servicesQuoteUnification                         25
#             viewItemPageMigrationDesktopReviewsNoTabs        11
# Name: experiment_name, dtype: int64

# %% [markdown]
# ## **A/B Test Bayesiano**

# %% [markdown]
# Una vez revisado todo lo anterior, lo siguiente sería realizar el A/B test para validar cual de las variantes es mejor. Esto lo haremos apoyandonos en el paqueta "[bayesian_testing](https://pypi.org/project/bayesian-testing/)" de python que permite evaluar A/B test desde un enfoque bayesiano.

# %%
# Inatalamos el paquete que vamos a utilizar
# !pip install bayesian_testing
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bayesian_testing
#   Downloading bayesian_testing-0.5.4-py3-none-any.whl (28 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.19.0 in /usr/local/lib/python3.9/dist-packages (from bayesian_testing) (1.22.4)
# Installing collected packages: bayesian_testing
# Successfully installed bayesian_testing-0.5.4

# %% [markdown]
# Vamos a trabajar con la opción para datos binarios ya que en este caso previamente hemos construido la variable de conversión compuesta por 1s y 0s.

# %%
# Importamos del paquete "bayesian_testing" el test para datos binarios
from bayesian_testing.experiments import BinaryDataTest

# %% [markdown]
# Inicialmente probamos de forma básica como funciona el test para algun experimento o algunas variables. Esto se hace de forma manual o programática para ir validando la información: En este caso vamos a tomar las primeras variantes de nuestro dataframe de resumen correspondiente al experimento "carousel-v2p-above-the-fold" que se compone de dos posibles variantes:

# %%
conv_test = BinaryDataTest()

variant_6787_conv = df_4['conversion_buy'][(df_4.variant_id == '6787')].values
variant_6786_conv = df_4['conversion_buy'][(df_4.variant_id == '6786')].values

conv_test.add_variant_data('6787', variant_6787_conv)
conv_test.add_variant_data('6786', variant_6786_conv)

conv_test.evaluate()
# Out:
# [{'variant': '6787',
#   'totals': 15091,
#   'positives': 369,
#   'positive_rate': 0.02445,
#   'posterior_mean': 0.02448,
#   'prob_being_best': 0.7371,
#   'expected_loss': 0.0002736},
#  {'variant': '6786',
#   'totals': 16148,
#   'positives': 377,
#   'positive_rate': 0.02335,
#   'posterior_mean': 0.02338,
#   'prob_being_best': 0.2629,
#   'expected_loss': 0.0013683}]

# %% [markdown]
# En el resultado anterior, podemos ver que la tasa de conversión, llamada "positive_rate" en este paquete, es mayor en la variante 6787, sin embargo, son bastante parecidas:
#
# 1. variant 6787: 2,445%
# 2. variant 6786: 2,335%
#
# Pero su probabilidad de ser el mejor ("prob_being_best") es bastante diferente:
#
# 1. variant 6787: 74,255%
# 2. variant 6786: 25,745%
#
# Siendo mucho mayor para la variante 6786 que para este experimentoo se consagraría como la variable con mayor probabilidad de finalizar en compra.

# %% [markdown]
# Una vez revisado lo anterior, vamos a crear un diccionario que nos permita almacecar los resultados del test: conv_test.evaluate() a cada uno de los experimentos del dataframe. Lo anterior lo vamos a complementar con una serie de iteraciones que nos permitan calcular la información por fecha, experimento y variante. Con ello podremos realizar comparaciones del tipo:
#
# El día DD-MM-YYYY el experimento XXX tuvo NNN variantes de las cuales la variante AAA presento una mayor probabilidad de ser la mejor.

# %%
# Creamos un diccionario para almacenar los resultados de la prueba
results = {}

# Iteramos sobre cada fecha
for date in df_4['date'].unique():

    # Creamos un diccionario para almacenar los resultados de los experimentos de la fecha actual
    date_results = {}
    
    # Seleccionamos los datos correspondientes a la fecha actual
    date_data = df_4.loc[df_4['date'] == date]
    
    # Iteramos sobre cada experimento de la fecha actual
    for experiment in date_data['experiment_name'].unique():

        # Seleccionamos los datos correspondientes al experimento actual
        experiment_data = date_data.loc[date_data['experiment_name'] == experiment]
        
        # Creamos un objeto BinaryDataTest vacío
        conv_test = BinaryDataTest()
        
        # Iteramos sobre cada variante del experimento actual
        for variant in experiment_data['variant_id'].unique():

            # Seleccionamos los datos correspondientes a la variante actual
            variant_data = experiment_data.loc[experiment_data['variant_id'] == variant, 'conversion_buy'].values

            # Añadimos los datos de la variante actual al objeto BinaryDataTest
            conv_test.add_variant_data(variant, variant_data)
        
        # Calculamos las probabilidades de que cada variante sea la mejor dentro del experimento actual
        probabilities = conv_test.evaluate()
        
        # Añadimos las probabilidades calculadas al diccionario de resultados del experimento actual
        date_results[experiment] = probabilities
    
    # Añadimos el diccionario de resultados de los experimentos de la fecha actual al diccionario principal
    results[date] = date_results

# Mostramos el diccionario construido con los resultados del test
results
# Out:
# {datetime.date(2021, 8, 2): {'viewItemPageMigrationDesktopReviewsNoTabs': [{'variant': '4856',
#     'totals': 11455,
#     'positives': 346,
#     'positive_rate': 0.03021,
#     'posterior_mean': 0.03025,
#     'prob_being_best': 0.46065,
#     'expected_loss': 0.0501402},
#    {'variant': 'DEFAULT',
#     'totals': 6,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.07143,
#     'prob_being_best': 0.53935,
#     'expected_loss': 0.0094932}],
#   'viewItemPageMigrationReturns': [{'variant': '5208',
#     'totals': 20025,
#     'positives': 466,
#     'positive_rate': 0.02327,
#     'posterior_mean': 0.02329,
#     'prob_being_best': 0.6616,
#     'expected_loss': 0.0124058},
#    {'variant': 'DEFAULT',
#     'totals': 19,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.025,
#     'prob_being_best': 0.3384,
#     'expected_loss': 0.0108409}],
#   'remove-ecn-tag': [{'variant': '4954',
#     'totals': 22429,
#     'positives': 555,
#     'positive_rate': 0.02474,
#     'posterior_mean': 0.02477,
#     'prob_being_best': 0.7305,
#     'expected_loss': 0.0083012},
#    {'variant': 'DEFAULT',
#     'totals': 24,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.02,
#     'prob_being_best': 0.2695,
#     'expected_loss': 0.0129796}],
#   'carousel-v2p-above-the-fold': [{'variant': '6787',
#     'totals': 11754,
#     'positives': 298,
#     'positive_rate': 0.02535,
#     'posterior_mean': 0.02539,
#     'prob_being_best': 0.544,
#     'expected_loss': 0.0070451},
#    {'variant': '6786',
#     'totals': 12748,
#     'positives': 309,
#     'positive_rate': 0.02424,
#     'posterior_mean': 0.02428,
#     'prob_being_best': 0.21915,
#     'expected_loss': 0.0081555},
#    {'variant': 'DEFAULT',
#     'totals': 26,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.01852,
#     'prob_being_best': 0.23685,
#     'expected_loss': 0.014199}],
#   'seller-with-tooltip': [{'variant': '4692',
#     'totals': 29997,
#     'positives': 652,
#     'positive_rate': 0.02174,
#     'posterior_mean': 0.02175,
#     'prob_being_best': 1.0,
#     'expected_loss': 0.0}],
#   'shippingCalculatorMigrationModalExperiment': [{'variant': '6551',
#     'totals': 26707,
#     'positives': 618,
#     'positive_rate': 0.02314,
#     'posterior_mean': 0.02316,
#     'prob_being_best': 0.7146,
#     'expected_loss': 0.0086487},
#    {'variant': 'DEFAULT',
#     'totals': 24,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.02,
#     'prob_being_best': 0.2854,
#     'expected_loss': 0.0118644}],
#   'showV2V3BoxMessages': [{'variant': '6430',
#     'totals': 31645,
#     'positives': 667,
#     'positive_rate': 0.02108,
#     'posterior_mean': 0.02109,
#     'prob_being_best': 0.76105,
#     'expected_loss': 0.0056433},
#    {'variant': 'DEFAULT',
#     'totals': 32,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.01515,
#     'prob_being_best': 0.23895,
#     'expected_loss': 0.0116642}],
#   'tendency-landing-enabled-MLA': [{'variant': '6980',
#     'totals': 4922,
#     'positives': 191,
#     'positive_rate': 0.03881,
#     'posterior_mean': 0.0389,
#     'prob_being_best': 1.0,
#     'expected_loss': 0.0}],
#   'escWebMLA': [{'variant': '2874',
#     'totals': 1085,
#     'positives': 709,
#     'positive_rate': 0.65346,
#     'posterior_mean': 0.65331,
#     'prob_being_best': 1.0,
#     'expected_loss': 0.0}],
#   'user-track': [{'variant': '6796',
#     'totals': 1169,
#     'positives': 764,
#     'positive_rate': 0.65355,
#     'posterior_mean': 0.65342,
#     'prob_being_best': 1.0,
#     'expected_loss': 0.0}],
#   'sa-on-vip': [{'variant': '6696',
#     'totals': 2128,
#     'positives': 56,
#     'positive_rate': 0.02632,
#     'posterior_mean': 0.02654,
#     'prob_being_best': 0.97565,
#     'expected_loss': 3.71e-05},
#    {'variant': '6695',
#     'totals': 2318,
#     'positives': 41,
#     'positive_rate': 0.01769,
#     'posterior_mean': 0.0179,
#     'prob_being_best': 0.02435,
#     'expected_loss': 0.0087051}],
#   'address_hub': [{'variant': '3574',
#     'totals': 946,
#     'positives': 763,
#     'positive_rate': 0.80655,
#     'posterior_mean': 0.80623,
#     'prob_being_best': 1.0,
#     'expected_loss': 0.0}],
#   'cpgShowOnlyAddToCart': [{'variant': '6690',
#     'totals': 68,
#     'positives': 3,
#     'positive_rate': 0.04412,
#     'posterior_mean': 0.05072,
#     'prob_being_best': 1.0,
#     'expected_loss': 0.0}],
#   'viewItemPageMigrationDesktopRES': [{'variant': '5941',
#     'totals': 1329,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.00038,
#     'prob_being_best': 1.0,
#     'expected_loss': 0.0}],
#   'HideTransitionModal': [{'variant': '6993',
#     'totals': 28,
#     'positives': 1,
#     'positive_rate': 0.03571,
#     'posterior_mean': 0.05172,
#     'prob_being_best': 0.48945,
#     'expected_loss': 0.0197972},
#    {'variant': 'DEFAULT',
#     'totals': 32,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.01515,
#     'prob_being_best': 0.07215,
#     'expected_loss': 0.0562759},
#    {'variant': '6646',
#     'totals': 32,
#     'positives': 1,
#     'positive_rate': 0.03125,
#     'posterior_mean': 0.04545,
#     'prob_being_best': 0.40555,
#     'expected_loss': 0.0259563},
#    {'variant': '6647',
#     'totals': 49,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.01,
#     'prob_being_best': 0.03285,
#     'expected_loss': 0.0616248}],
#   'secure_card': [{'variant': '4612',
#     'totals': 21,
#     'positives': 21,
#     'positive_rate': 1.0,
#     'posterior_mean': 0.97727,
#     'prob_being_best': 1.0,
#     'expected_loss': 0.0}],
#   'viewItemPageMigrationDesktopQuotableSRV': [{'variant': '7179',
#     'totals': 40,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.0122,
#     'prob_being_best': 0.23935,
#     'expected_loss': 0.0629255},
#    {'variant': '7178',
#     'totals': 6,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.07143,
#     'prob_being_best': 0.76065,
#     'expected_loss': 0.0038068}],
#   'viewItemPageMigrationDesktopHirableSRV': [{'variant': '7174',
#     'totals': 50,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.0098,
#     'prob_being_best': 0.18155,
#     'expected_loss': 0.0919747},
#    {'variant': '7175',
#     'totals': 4,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.1,
#     'prob_being_best': 0.81845,
#     'expected_loss': 0.0023714}],
#   'viewItemPageMigrationDesktopRESDev': [{'variant': '6861',
#     'totals': 5,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.08333,
#     'prob_being_best': 1.0,
#     'expected_loss': 0.0}],
#   'compatibilityWidget': [{'variant': '5539',
#     'totals': 19,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.025,
#     'prob_being_best': 1.0,
#     'expected_loss': 0.0}],
#   'assetsCdnDomainMLA': [{'variant': 'DEFAULT',
#     'totals': 10,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.04545,
#     'prob_being_best': 1.0,
#     'expected_loss': 0.0}],
#   'classiWordingFree': [{'variant': '2826',
#     'totals': 10,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.04545,
#     'prob_being_best': 1.0,
#     'expected_loss': 0.0}],
#   'servicesQuoteUnification': [{'variant': 'DEFAULT',
#     'totals': 10,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.04545,
#     'prob_being_best': 1.0,
#     'expected_loss': 0.0}]},
#  datetime.date(2021, 8, 1): {'viewItemPageMigrationReturns': [{'variant': '5208',
#     'totals': 5151,
#     'positives': 98,
#     'positive_rate': 0.01903,
#     'posterior_mean': 0.01912,
#     'prob_being_best': 0.41115,
#     'expected_loss': 0.0474532},
#    {'variant': 'DEFAULT',
#     'totals': 7,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.0625,
#     'prob_being_best': 0.58885,
#     'expected_loss': 0.0053727}],
#   'remove-ecn-tag': [{'variant': '4954',
#     'totals': 6042,
#     'positives': 127,
#     'positive_rate': 0.02102,
#     'posterior_mean': 0.0211,
#     'prob_being_best': 0.446,
#     'expected_loss': 0.0409165},
#    {'variant': 'DEFAULT',
#     'totals': 8,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.05556,
#     'prob_being_best': 0.554,
#     'expected_loss': 0.0064347}],
#   'carousel-v2p-above-the-fold': [{'variant': '6786',
#     'totals': 3400,
#     'positives': 68,
#     'positive_rate': 0.02,
#     'posterior_mean': 0.02014,
#     'prob_being_best': 0.15895,
#     'expected_loss': 0.0429396},
#    {'variant': '6787',
#     'totals': 3337,
#     'positives': 71,
#     'positive_rate': 0.02128,
#     'posterior_mean': 0.02142,
#     'prob_being_best': 0.29555,
#     'expected_loss': 0.0416326},
#    {'variant': 'DEFAULT',
#     'totals': 8,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.05556,
#     'prob_being_best': 0.5455,
#     'expected_loss': 0.006841}],
#   'seller-with-tooltip': [{'variant': '4692',
#     'totals': 8533,
#     'positives': 152,
#     'positive_rate': 0.01781,
#     'posterior_mean': 0.01787,
#     'prob_being_best': 1.0,
#     'expected_loss': 0.0}],
#   'shippingCalculatorMigrationModalExperiment': [{'variant': '6551',
#     'totals': 7363,
#     'positives': 139,
#     'positive_rate': 0.01888,
#     'posterior_mean': 0.01894,
#     'prob_being_best': 0.4424,
#     'expected_loss': 0.0367804},
#    {'variant': 'DEFAULT',
#     'totals': 9,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.05,
#     'prob_being_best': 0.5576,
#     'expected_loss': 0.0057262}],
#   'showV2V3BoxMessages': [{'variant': '6430',
#     'totals': 8978,
#     'positives': 154,
#     'positive_rate': 0.01715,
#     'posterior_mean': 0.01721,
#     'prob_being_best': 0.491,
#     'expected_loss': 0.0267391},
#    {'variant': 'DEFAULT',
#     'totals': 12,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.03846,
#     'prob_being_best': 0.509,
#     'expected_loss': 0.0057823}],
#   'viewItemPageMigrationDesktopReviewsNoTabs': [{'variant': '4856',
#     'totals': 3330,
#     'positives': 83,
#     'positive_rate': 0.02492,
#     'posterior_mean': 0.02507,
#     'prob_being_best': 0.39155,
#     'expected_loss': 0.0654208},
#    {'variant': 'DEFAULT',
#     'totals': 5,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.08333,
#     'prob_being_best': 0.60845,
#     'expected_loss': 0.006708}],
#   'address_hub': [{'variant': '3574',
#     'totals': 225,
#     'positives': 171,
#     'positive_rate': 0.76,
#     'posterior_mean': 0.75885,
#     'prob_being_best': 1.0,
#     'expected_loss': 0.0}],
#   'escWebMLA': [{'variant': '2874',
#     'totals': 247,
#     'positives': 148,
#     'positive_rate': 0.59919,
#     'posterior_mean': 0.59879,
#     'prob_being_best': 1.0,
#     'expected_loss': 0.0}],
#   'user-track': [{'variant': '6796',
#     'totals': 277,
#     'positives': 173,
#     'positive_rate': 0.62455,
#     'posterior_mean': 0.6241,
#     'prob_being_best': 1.0,
#     'expected_loss': 0.0}],
#   'sa-on-vip': [{'variant': '6696',
#     'totals': 727,
#     'positives': 15,
#     'positive_rate': 0.02063,
#     'posterior_mean': 0.02129,
#     'prob_being_best': 0.899,
#     'expected_loss': 0.0003432},
#    {'variant': '6695',
#     'totals': 672,
#     'positives': 8,
#     'positive_rate': 0.0119,
#     'posterior_mean': 0.01263,
#     'prob_being_best': 0.101,
#     'expected_loss': 0.0090114}],
#   'tendency-landing-enabled-MLA': [{'variant': '6980',
#     'totals': 1462,
#     'positives': 48,
#     'positive_rate': 0.03283,
#     'posterior_mean': 0.03315,
#     'prob_being_best': 1.0,
#     'expected_loss': 0.0}],
#   'assetsCdnDomainMLA': [{'variant': 'DEFAULT',
#     'totals': 15,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.03125,
#     'prob_being_best': 1.0,
#     'expected_loss': 0.0}],
#   'viewItemPageMigrationDesktopQuotableSRV': [{'variant': '7178',
#     'totals': 11,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.04167,
#     'prob_being_best': 0.2654,
#     'expected_loss': 0.1400294},
#    {'variant': '7179',
#     'totals': 2,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.16667,
#     'prob_being_best': 0.7346,
#     'expected_loss': 0.0135141}],
#   'classiWordingFree': [{'variant': '2826',
#     'totals': 15,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.03125,
#     'prob_being_best': 1.0,
#     'expected_loss': 0.0}],
#   'servicesQuoteUnification': [{'variant': 'DEFAULT',
#     'totals': 15,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.03125,
#     'prob_being_best': 1.0,
#     'expected_loss': 0.0}],
#   'viewItemPageMigrationDesktopRES': [{'variant': '5941',
#     'totals': 426,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.00117,
#     'prob_being_best': 1.0,
#     'expected_loss': 0.0}],
#   'cpgShowOnlyAddToCart': [{'variant': '6690',
#     'totals': 30,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.01613,
#     'prob_being_best': 1.0,
#     'expected_loss': 0.0}],
#   'HideTransitionModal': [{'variant': 'DEFAULT',
#     'totals': 12,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.03846,
#     'prob_being_best': 0.0861,
#     'expected_loss': 0.1993404},
#    {'variant': '6993',
#     'totals': 7,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.0625,
#     'prob_being_best': 0.1666,
#     'expected_loss': 0.1738472},
#    {'variant': '6646',
#     'totals': 2,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.16667,
#     'prob_being_best': 0.465,
#     'expected_loss': 0.0705001},
#    {'variant': '6647',
#     'totals': 4,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.1,
#     'prob_being_best': 0.2823,
#     'expected_loss': 0.135996}],
#   'viewItemPageMigrationDesktopHirableSRV': [{'variant': '7175',
#     'totals': 4,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.1,
#     'prob_being_best': 0.465,
#     'expected_loss': 0.0786994},
#    {'variant': '7174',
#     'totals': 3,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.125,
#     'prob_being_best': 0.535,
#     'expected_loss': 0.0560905}],
#   'secure_card': [{'variant': '4612',
#     'totals': 4,
#     'positives': 4,
#     'positive_rate': 1.0,
#     'posterior_mean': 0.9,
#     'prob_being_best': 1.0,
#     'expected_loss': 0.0}],
#   'compatibilityWidget': [{'variant': '5539',
#     'totals': 2,
#     'positives': 0,
#     'positive_rate': 0.0,
#     'posterior_mean': 0.16667,
#     'prob_being_best': 1.0,
#     'expected_loss': 0.0}]}}

# %% [markdown]
# Lo anterior ha dejado guardados los resultados en un diccionario. Ahora, como lo hicimos al comienzo, vamos a transformar ese diccionario en un dataframe que nos permita visualizar mejor la información y realizar comparaciones entre experimentos por fecha, experimento y variantes junto a todas las métricas calculadas:

# %%
# Creamos una lista vacía para almacenar los datos de cada experimento
data = []

# Iteramos sobre cada fecha en el diccionario
for date, experiments in results.items():

    # Iteramos sobre cada experimento en la fecha
    for experiment_name, variants in experiments.items():

        # Iteramos sobre cada variante en el experimento
        for variant_data in variants:

            # Exrtreamos los datos de variant_data
            variant = variant_data['variant']
            totals = variant_data['totals']
            positives = variant_data['positives']
            positive_rate = variant_data['positive_rate']
            posterior_mean = variant_data['posterior_mean']
            prob_being_best = variant_data['prob_being_best']
            expected_loss = variant_data['expected_loss']

            # Creamos un diccionario paara variant_data
            variant_dict = {'date': date,
                            'experiment_name': experiment_name,
                            'variant_id': variant,
                            'totals': totals,
                            'positives': positives,
                            'positive_rate': positive_rate,
                            'posterior_mean': posterior_mean,
                            'prob_being_best': prob_being_best,
                            'expected_loss': expected_loss}

            # Agregamos los datos del diccionario a la lista vacia que creamos al inicio
            data.append(variant_dict)

# Creamos un dataframe a partir de la lista "data"
results_df = pd.DataFrame(data)

# Ordernamos el dataframe
results_df = results_df.sort_values(['date', 'experiment_name', 'variant_id', 'positive_rate'], ascending = [True, True, True, True], ignore_index=True)

# Imprimimos el dataframe final
results_df
# Out:
#           date                            experiment_name variant_id  totals  \
# 0   2021-08-01                        HideTransitionModal       6646       2
# 1   2021-08-01                        HideTransitionModal       6647       4
# 2   2021-08-01                        HideTransitionModal       6993       7
# 3   2021-08-01                        HideTransitionModal    DEFAULT      12
# 4   2021-08-01                                address_hub       3574     225
# ..         ...                                        ...        ...     ...
# 66  2021-08-02         viewItemPageMigrationDesktopRESDev       6861       5
# 67  2021-08-02  viewItemPageMigrationDesktopReviewsNoTabs       4856   11455
# 68  2021-08-02  viewItemPageMigrationDesktopReviewsNoTabs    DEFAULT       6
# 69  2021-08-02               viewItemPageMigrationReturns       5208   20025
# 70  2021-08-02               viewItemPageMigrationReturns    DEFAULT      19
#
#     positives  positive_rate  posterior_mean  prob_being_best  expected_loss
# 0           0        0.00000         0.16667          0.46500       0.070500
# 1           0        0.00000         0.10000          0.28230       0.135996
# 2           0        0.00000         0.06250          0.16660       0.173847
# 3           0        0.00000         0.03846          0.08610       0.199340
# 4         171        0.76000         0.75885          1.00000       0.000000
# ..        ...            ...             ...              ...            ...
# 66          0        0.00000         0.08333          1.00000       0.000000
# 67        346        0.03021         0.03025          0.46065       0.050140
# 68          0        0.00000         0.07143          0.53935       0.009493
# 69        466        0.02327         0.02329          0.66160       0.012406
# 70          0        0.00000         0.02500          0.33840       0.010841
#
# [71 rows x 9 columns]

# %% [markdown]
# Justamente el dataframe anterior, nos permite comparar por fecha, todas las posibles variantes por experimento y comparar la cantidad de usuarios que vieron el experimento, la cantidad de usuarios cuya cadena de navegación termino en compra luego de ver el experimento ('positives'), la tasa de conversión ('positive_rate') y sobretodo, la probabilidad de que esa variante sea la mejor entre todas las posibles variantes del experimento ('prob_being_best')

# %% [markdown]
# ## **Implementar API**

# %% [markdown]
# Ahora para la implementación de la API vamos a crear un dataframe mas pequeño donde tengamos solamente las variables que necesitamos:

# %%
# Creamos un dataframe mas pequeño con las variables a usar en la API
results_df_api = results_df[['date','experiment_name', 'variant_id', 'totals', 'positives']].drop_duplicates()
results_df_api
# Out:
#           date                            experiment_name variant_id  totals  \
# 0   2021-08-01                        HideTransitionModal       6646       2
# 1   2021-08-01                        HideTransitionModal       6647       4
# 2   2021-08-01                        HideTransitionModal       6993       7
# 3   2021-08-01                        HideTransitionModal    DEFAULT      12
# 4   2021-08-01                                address_hub       3574     225
# ..         ...                                        ...        ...     ...
# 66  2021-08-02         viewItemPageMigrationDesktopRESDev       6861       5
# 67  2021-08-02  viewItemPageMigrationDesktopReviewsNoTabs       4856   11455
# 68  2021-08-02  viewItemPageMigrationDesktopReviewsNoTabs    DEFAULT       6
# 69  2021-08-02               viewItemPageMigrationReturns       5208   20025
# 70  2021-08-02               viewItemPageMigrationReturns    DEFAULT      19
#
#     positives
# 0           0
# 1           0
# 2           0
# 3           0
# 4         171
# ..        ...
# 66          0
# 67        346
# 68          0
# 69        466
# 70          0
#
# [71 rows x 5 columns]

# %% [markdown]
# Para la creación de la API local, se utilizo el paquete [flask](https://flask.palletsprojects.com/en/2.2.x/api/), que nos permite definir la estructura de salida en el formato json que se solicitó y programar los parametros que se requieren para la consulta a traves de la URL con el metodo GET:

# %%
from flask import Flask, jsonify, request

app = Flask(__name__)

@app.route('/experiment/<experiment_id>/result')
def get_experiment_results(experiment_id):

    # Obtenemos el valor del parámetro "day" para la solicitud HTTP
    day = request.args.get('day')
    
    # Validamos que la fecha proporcionada es correcta, de lo contrario mostrara el error "fecha invalida"
    try:
        day = pd.Timestamp(day).floor('D')
    except ValueError:
        return jsonify({'error': 'fecha invalida'}), 400
    
    # Filtramos los datos del dataframe para obtener los resultados del día y experimento que deseamos conocer
    filtered_results = results_df_api[(results_df_api['date'] == day) & (results_df_api['experiment_name'] == experiment_id)]
    
    # Si no hay resultados para ese día y ese experimento, se muestra el error "experimento no encontrado"
    if filtered_results.empty:
        return jsonify({'error': 'experimento no encontrado'}), 404
    
    # Calculamos los resultados requeridos, en este caso, total de participantes y total de compras
    total_participants = filtered_results['totals'].sum()
    winners = filtered_results.loc[filtered_results['positives'].idxmax(), 'variant_id']
    variants = []
    for index, row in filtered_results.iterrows():
        variants.append({
            'id': row['variant_id'],
            'numero_de_compras': str(row['positives'])
        })
    
    # Presentamos los resultados en el formato requerido
    results = {
        experiment_id: {
            'numero_de_participantes': str(total_participants),
            'ganador': winners,
            'variantes': variants
        }
    }
    return jsonify({'resultados': results})

# Iniicamos la API en el local host
if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# 2023-03-28 18:24:04,003 - werkzeug - INFO - WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# 2023-03-28 18:24:04,004 - werkzeug - INFO - Press CTRL+C to quit

# %% [markdown]
# Es importante tener en cuenta que mientras la celda anterior se este ejecutando podremos realizar consultas a la API respectando la  estructura solicitada. Dichas consultas las podremos hacer a traves de nuestro navegador web o de alguna herramienta de desarrollo de API como son [Insomnia](https://insomnia.rest/) y [Postman](https://www.postman.com/). En este caso hemos probado algunos casos sobre los que retornan los siguientes resultados en la herramienta [Insomnia](https://insomnia.rest/):
#
# 1. http://localhost:5000/experiment/sa-on-vip/result?day=2021-08-01
#
# <figure>
# <img src='https://raw.githubusercontent.com/JdrSosa/MELI/main/Insomnia%20-%20sa-on-vip.png' width="1200" height="500" />
# <figcaption></figcaption>
# </figure>
#
# 2. http://localhost:5000/experiment/viewItemPageMigrationDesktopReviewsNoTabs/result?day=2021-08-01
#
# <figure>
# <img src='https://raw.githubusercontent.com/JdrSosa/MELI/main/Insomnia%20-%20viewItemPageMigrationDesktopReviewsNoTabs.png' width="1200" height="500" />
# <figcaption></figcaption>
# </figure>
#
# 3. http://localhost:5000/experiment/abc/result?day=2021-08-01
#
# <figure>
# <img src='https://raw.githubusercontent.com/JdrSosa/MELI/main/Insomnia%20-%20abc.png' width="1200" height="500" />
# <figcaption></figcaption>
# </figure>
